# %% [markdown]
# # 자율주행을 위한 3구 가로 신호등 인식하기
#
#
# **3구 가로 신호등 데이터 조건**
# - class = 'traffic_light'
# - type = 'car'
# - direction = 'horizontal'
# - light_count = '3'

# %% [markdown]
# ### 패키지 임포트

# %%
import json
import pandas as pd
import os
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ### value값으로 key값 찾기

# %%
def find_key(dict, val):
    return [key for key, value in dict.items() if value == val]
    # return next(key for key, value in dict.items() if value == val)

# %% [markdown]
# ### 신호등 이미지 잘라서 저장하기

# %%
light = [] # 3구 신호등만 담을 리스트

filepath = "data/training/train_daylight_label"    # json 경로
imagepath = "data/training/train_daylight_image"    # 이미지 경로

# json 경로
classes = os.listdir(filepath)

# 색상 저장할 상위 폴더
dir_path = './data_color'
# dir_path 폴더 없으면 생성
if os.path.isdir(dir_path) == False:
    os.mkdir(dir_path)

    
for i, cls in enumerate(classes):
#     print("Openinig " + cls + "/")

    image_cnt = 0 # 이미지 저장할때 순번쓰려고 변수 선언
    
    data =  json.load(open(filepath + "/" + cls))
    df = pd.DataFrame(data["annotation"])
    
    # 이렇게 하나씩 조건문 걸어서 해줘야해요? 왜 컬럼이 없고 난리세요,, 뭐 다른 방법 없나요?
    if not df.empty:
        # 신호등만 (도로표지판 걸러)
        filter1 = (df['class'] == 'traffic_light')
        df = df[filter1]
        
        if not df.empty:
            # 자동차 신호등만 (보행자 신호등 걸러)
            filter2 = (df['type'] == 'car')
            df = df[filter2]
            
            if not df.empty:
                # 3구 신호등만
                filter3 = (df['light_count'] == '3')
                df = df[filter3]
                
                if not df.empty:
                    # 가로 신호등만 (세로 걸러)
                    filter4 = (df['direction'] == 'horizontal')
                    df = df[filter4]
                    
                    light.append(cls) # 필터링된 3구 가로 신호등 리스트에 담기
                    
                    # 이미지 가져오기
                    name = (os.path.splitext(cls))[0]    # json 확장자 빼기
                    image1 = name + ".jpg"
                    image = Image.open(imagepath + '/' + image1)
                    
                    
                    print("파일명 : ", cls)
                    for j in range(len(df['box'])):
                        image_cnt += 1
                        box = df['box'][j:j+1]
                        
                        # 박스 좌표 가져오기
                        x = box.str.get(0)
                        y = box.str.get(1)
                        w = box.str.get(2)
                        h = box.str.get(3)
                        
                        # 이미지 영역 자르기
                        croppedImage = image.crop((x, y, w, h))
                        
                        for attr in df['attribute'][j:j+1].str.get(0):
                            print("attr : ", attr)
                            try: 
                                color = find_key(attr, 'on')    # value값으로 key값 찾는 함수 호출
                                color = color[0]    # 첫번째 값으로 정함. (추후 수정 예정)
                            except: # 신호등에 불이 다 꺼져있을 경우
                                color = 'light_off'

                        # 신호등 색깔 폴더 경로
                        folder_path = dir_path + '/' + color

                        # 폴더 없으면 생성
                        if os.path.isdir(folder_path) == False:
                            os.mkdir(folder_path)

                        # 이미지 폴더에 저장
                        croppedImage.save(folder_path + '/' + name + "_" + str(image_cnt) + '.jpg', format = None)
                        
                    print("************************************************************")
# Out:
# 파일명 :  13648070.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13648071.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13648115.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649018.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649019.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649020.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649021.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649022.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'on', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649023.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649024.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649025.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649026.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649027.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649028.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649029.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649030.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649031.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649032.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649033.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649034.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649035.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649036.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649037.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649038.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649039.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649040.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649041.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649044.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649045.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649046.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649047.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649353.json
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649356.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649357.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649358.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649359.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649360.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649361.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649362.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649363.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649364.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649365.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649367.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649368.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649369.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649370.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649371.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649372.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649373.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649421.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649422.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649423.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649424.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649425.json
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649657.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649658.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649659.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649660.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649661.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649662.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13649663.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650094.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650097.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650110.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650111.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650112.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650113.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13650114.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13663449.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13668145.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13668146.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13668147.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13668157.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13668158.json
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681155.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681156.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681157.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681158.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681185.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681186.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681187.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681188.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681189.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681190.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681191.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681192.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681193.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681194.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681195.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681420.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681427.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681432.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681439.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681440.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681441.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681442.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681511.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681512.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681513.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681514.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681515.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681516.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681517.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681518.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681519.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681564.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681565.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681566.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681567.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  13681929.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681930.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681931.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13681932.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}
# ************************************************************
# 파일명 :  13690741.json
# ...
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220774.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220775.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220777.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220781.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220783.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220785.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220786.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220787.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220788.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220789.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220790.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220791.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220792.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220793.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220797.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220811.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220812.json
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'on', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220813.json
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220814.json
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# attr :  {'red': 'off', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'on', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220815.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220816.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220817.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220818.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220819.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220820.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220821.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220822.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220823.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220824.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220825.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220826.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220827.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220828.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220829.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************
# 파일명 :  a16220830.json
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# attr :  {'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'off'}
# ************************************************************

# %%
#data = pd.read_json('./data/training/label_daylight/daylight/s01000200.json')
data = json.load(open('./data/training/train_daylight_label/13681189.json'))
df = pd.DataFrame(data["annotation"])
print(list(df['attribute']))
# Out:
# [nan, [{'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}], [{'red': 'on', 'green': 'off', 'x_light': 'off', 'others_arrow': 'off', 'yellow': 'off', 'left_arrow': 'on'}]]
